# %% [raw]
# Answer 1:
#
# When creating custom exceptions in a programming language, it is common to derive them from the built-in exception class provided by the language. Here are some reasons why using the exception class is beneficial:
#
# Consistency with Language Conventions:
#
# By inheriting from the base exception class in the language, your custom exception adheres to the conventions and patterns established by the language itself. This helps other developers understand and use your custom exception more easily.
#
# Error Handling:
#
# Exception classes provide a standardized way of handling errors. When a custom exception inherits from the base exception class, it can be caught using the same mechanisms as built-in exceptions, making error handling more consistent and predictable.
#
# Polymorphism:
#
# In many object-oriented programming languages, including Python and Java, using the base exception class allows your custom exception to be treated polymorphically with other exceptions. This means that your custom exception can be caught in the same except block as its parent class, facilitating a more generalized error-handling approach.
#
# Extensibility:
#
# If you need to extend or modify the behavior of your custom exception in the future, inheriting from the exception class allows you to easily override methods or attributes defined in the base class without having to reimplement the entire exception handling logic.
#
# Compatibility with Exception Hierarchy:
#
# Many programming languages have a hierarchical structure for exceptions. For instance, in Python, all exceptions inherit from the base Exception class. This hierarchy allows for more specific exceptions to be caught before more general ones. By following this convention, you integrate your custom exception seamlessly into this hierarchy.

# %% [markdown]
# Answer 2:In Python, the exception hierarchy can be visualized using the BaseException class. You can create a program that iterates through the exception hierarchy and prints the names of the exception classes. Here's a simple example:

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)

if __name__ == "__main__":
    print("Python Exception Hierarchy:")
    print_exception_hierarchy(BaseException)
# Out:
# Python Exception Hierarchy:
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       itimer_error
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
#       Error
# ...

# %% [raw]
# This program defines a function print_exception_hierarchy that recursively prints the names of exception classes and their subclasses. The starting point is the BaseException class, the root of the exception hierarchy in Python. When you run this program, it will print the exception hierarchy

# %% [raw]
# Answer 3:
# In Python, the ArithmeticError class is the base class for various arithmetic-related exceptions. Two notable exceptions derived from ArithmeticError are ZeroDivisionError and OverflowError.
#
# ZeroDivisionError:
#
# This exception is raised when attempting to divide a number by zero. Division by zero is mathematically undefined, and attempting to perform such an operation in Python leads to a ZeroDivisionError. Here's an example:

# %%
try:
    result = 10 / 0  # Attempting to divide by zero
except ZeroDivisionError as e:
    print(f"Error: {e}")
# Out:
# Error: division by zero

# %% [raw]
# OverflowError:
#
# This exception is raised when the result of an arithmetic operation exceeds the representational limits of the data type. For example, trying to calculate an exponentiation that results in a very large number may lead to an OverflowError. Here's an example:

# %%
try:
    result = 2 ** 1000  
except OverflowError as e:
    print(f"Error: {e}")

# %% [raw]
# Answer 4:
# In Python, the LookupError is a base class for exceptions that occur when a lookup or indexing operation fails. Two common exceptions derived from LookupError are KeyError and IndexError. Let's explore each of them with examples:
#
# KeyError:
#
# This exception is raised when you try to access a dictionary key that doesn't exist. Here's an example:

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}

try:
    value = my_dict['d']  # Attempting to access a key that doesn't exist
except KeyError as e:
    print(f"Error: {e}")
# Out:
# Error: 'd'

# %% [raw]
# In this example, the dictionary my_dict does not have a key 'd', so attempting to access it results in a KeyError. Handling KeyError allows you to gracefully manage cases where a specific key is not present in a dictionary.
#
# IndexError:
#
# This exception is raised when you try to access an index in a sequence (e.g., list, tuple, or string) that is outside the valid range. Here's an example:

# %%
my_list = [1, 2, 3, 4, 5]

try:
    value = my_list[10]  # Attempting to access an index outside the range
except IndexError as e:
    print(f"Error: {e}")
# Out:
# Error: list index out of range

# %% [raw]
# In this example, the list my_list has only indices 0 to 4, so attempting to access index 10 results in an IndexError. Handling IndexError is important to prevent unintended crashes when working with sequences.

# %% [raw]
# Answer 5:
#
# ImportError is a base class for exceptions that occur when an import statement fails in Python. One common exception derived from ImportError is ModuleNotFoundError. Let's explore both in more detail:
#
# ImportError:
#
# This exception is raised when an import statement cannot locate the module to be imported. It can occur for various reasons, such as a typo in the module name, an issue with the module's structure, or the module being in a location that is not in the Python search path. Here's a generic example:

# %%
try:
    import non_existent_module  # Attempting to import a module that doesn't exist
except ImportError as e:
    print(f"ImportError: {e}")
# Out:
# ImportError: No module named 'non_existent_module'

# %% [raw]
# ModuleNotFoundError:
#
# ModuleNotFoundError is a more specific subclass of ImportError introduced in Python 3.6. It is raised when a module could not be found during import. The structure of the error message is more informative than a generic ImportError. Here's an example:

# %%
try:
    import non_existent_module  # Attempting to import a module that doesn't exist
except ModuleNotFoundError as e:
    print(f"ModuleNotFoundError: {e}")
# Out:
# ModuleNotFoundError: No module named 'non_existent_module'

# %% [raw]
# Answer 6:
#
# Exception handling is an important aspect of writing robust and maintainable Python code. Here are some best practices for exception handling in Python:
#
# Use Specific Exceptions:
#
# Catch specific exceptions rather than using broad, general catch-all constructs. This allows you to handle different errors in different ways and provides better clarity about the issues in your code.
# python
#
#
#
# try:
#     # Code that may raise specific exceptions
# except SpecificError as se:
#     # Handle SpecificError
# except AnotherSpecificError as ase:
#     # Handle AnotherSpecificError
#
#
# Avoid Bare Excepts:
#
# Avoid using bare except clauses without specifying the exception type. This can mask errors and make debugging challenging. Always catch the specific exceptions you expect.
# python
#
#
#
# # Avoid this:
# try:
#     # Code that may raise any exception
# except:
#     # Handle any exception
#
# # Prefer this:
# try:
#     # Code that may raise specific exceptions
# except SpecificError as se:
#     # Handle SpecificError
#
#
# Use Finally for Cleanup:
#
# Use the finally block for cleanup operations that must be executed whether an exception occurs or not. Common use cases include closing files or releasing resources.
# python
#
#
#
# try:
#     # Code that may raise exceptions
# except SpecificError as se:
#     # Handle SpecificError
# finally:
#     # Cleanup code (always executed)
#
# Logging Exceptions:
#
# Use the logging module to log exceptions. This helps in debugging and provides a record of what went wrong, especially in production environments.
# python
#
#
# import logging
#
# try:
#     # Code that may raise exceptions
# except SpecificError as se:
#     logging.error(f"An error occurred: {se}")
#
#
# Handle Exceptions Close to the Source:
#
#
# Handle exceptions as close to the source as possible. This makes the code more readable and helps to identify the point of failure quickly.
# python
#
#
# def example_function():
#     try:
#         # Code that may raise exceptions
#     except SpecificError as se:
#         # Handle SpecificError
#
#
# Raise Exceptions Explicitly:
#
# Raise exceptions explicitly when you encounter an error condition that cannot be handled locally. This allows higher-level code to deal with the exceptional situation.
# python
#
#
# if some_condition:
#     raise CustomError("This is a custom exception")
# Use Context Managers:
#
#
# Utilize context managers (e.g., with statements) to ensure proper resource management and reduce the need for explicit try-finally blocks.
# python
#
#
# with open("example.txt", "r") as file:
#     # Code that uses the file
#
# Document Exception Handling:
#
# Document the exceptions that a function or method may raise. This makes it easier for other developers (and future-you) to understand the expected behavior and handle exceptions appropriately.
# python
#
#
# def example_function():
#     """
#     This function may raise SpecificError if a certain condition is met.
#     """
#     try:
#         # Code that may raise SpecificError
#     except SpecificError as se:
#         # Handle SpecificError
#         pass
#
# Keep Exception Handling Simple:
#
# Avoid overly complex exception handling logic. If the exception cannot be handled locally, let it propagate up the call stack to higher-level code that can handle it more appropriately.
# Test Exception Handling:
